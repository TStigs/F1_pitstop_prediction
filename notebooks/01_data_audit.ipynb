# %% [markdown]
# # 01. Data Audit: F1 Pit Stop Prediction
# Inspect dataset shapes, column data types, missing values, target balance, and race/driver metadata.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from src.data import load_raw_data, get_data_summary

# %%
train, test, sub = load_raw_data('../data/raw')
print('Train shape:', train.shape)
print('Test shape: ', test.shape)

# %%
get_data_summary(train, 'Train')

# %%
get_data_summary(test, 'Test')
